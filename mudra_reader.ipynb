# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\lenovo\\Desktop\\minor_sem6\\code\\icd_project'

# %%
import pandas as pd
import ast

df = pd.read_csv("./data/mudras.csv")

# Convert string lists to actual Python lists
df["meanings"] = df["meanings"].apply(ast.literal_eval)
df["viniyoga"] = df["viniyoga"].apply(ast.literal_eval)

df.head(20)
# Out:
#        id         category sanskrit_name transliteration         english_name  \
# 0   ASH01  Asamyukta Hasta          पताक          Pataka                 Flag
# 1   ASH02  Asamyukta Hasta      त्रिपताक       Tripataka  Three Parts of Flag
# 2   ASH03  Asamyukta Hasta     कर्तरीमुख    Kartarimukha         Scissor Face
# 3   ASH04  Asamyukta Hasta    अर्धचन्द्र    Ardhachandra            Half Moon
# 4   ASH05  Asamyukta Hasta          अराल           Arala                 Bent
# 5   ASH06  Asamyukta Hasta      शुकतुण्ड      Shukatunda          Parrot Beak
# 6   ASH07  Asamyukta Hasta        मुष्टि          Mushti                 Fist
# 7   ASH08  Asamyukta Hasta          शिखर        Shikhara                 Peak
# 8   ASH09  Asamyukta Hasta        कपित्थ        Kapittha           Wood Apple
# 9   ASH10  Asamyukta Hasta        कटकमुख     Katakamukha     Opening Bracelet
# 10  ASH11  Asamyukta Hasta       सूचीमुख      Suchimukha          Needle Face
# 11  ASH12  Asamyukta Hasta       पद्मकोश      Padmakosha            Lotus Bud
# 12  ASH13  Asamyukta Hasta     सर्पशीर्ष    Sarpashirsha         Serpent Head
# 13  ASH14  Asamyukta Hasta      मृगशीर्ष    Mrigashirsha            Deer Head
# 14  ASH15  Asamyukta Hasta       सिंहमुख      Simhamukha            Lion Face
# 15  ASH16  Asamyukta Hasta         कंगुल         Kangula                 Bell
# 16  ASH17  Asamyukta Hasta        अलपद्म        Alapadma  Fully Bloomed Lotus
# 17  ASH18  Asamyukta Hasta          चतुर         Chatura               Clever
# 18  ASH19  Asamyukta Hasta         भ्रमर        Bhramara                  Bee
# 19  ASH20  Asamyukta Hasta       हंसास्य        Hamsasya            Swan Beak
#
#                                              meanings  \
# 0   [clouds, forest, night, river, wind, denial, b...
# 1   [crown, tree, arrow, flame, thunder, weapon, k...
# 2   [separation, opposition, lightning, corner, cr...
# 3   [moon, plate, spear, meditation, blessing, wai...
# 4   [drinking poison, wind, intoxication, violent ...
# 5   [shooting arrow, small bird, calling, secrecy,...
# 6   [anger, firmness, strength, wrestling, holding...
# 7   [bow, pillar, husband, embrace, question, lip,...
# 8   [Lakshmi, Saraswati, milking cow, holding cymb...
# 9   [holding garland, plucking flowers, embrace, n...
# 10  [one, city, sun, truth, instruction, pointing,...
# 11  [fruit, flower bud, ball, offering, breast, heap]
# 12  [snake, water sprinkling, feeding, massage, po...
# 13  [deer, woman, flute, calling, face, cheek, que...
# 14  [lion, herbs, pearl, coral, medicine, strong e...
# 15         [bell, small fruit, betel nut, flower bud]
# 16  [lotus, beauty, mirror, circular form, full mo...
# 17  [intellect, less, gold, oil, gentleness, shyness]
# 18     [bee, parrot, whisper, cuckoo, small creature]
# 19  [pearl, tying thread, wisdom, delicacy, drawin...
#
#                                           description  \
# 0   All fingers extended and joined, thumb slightl...
# 1                   Ring finger bent, others extended
# 2         Index and middle finger split like scissors
# 3       All fingers extended, thumb stretched outward
# 4                    Index finger bent, others closed
# 5                       Index finger curved like beak
# 6                                         Closed fist
# 7                              Fist with thumb raised
# 8              Fist with index finger bent over thumb
# 9                      Thumb, index and middle joined
# 10               Index finger extended, others closed
# 11                Fingers curved forming hollow shape
# 12             Fingers together bent slightly forward
# 13     Thumb, ring and little joined, others extended
# 14             Thumb touching middle and ring fingers
# 15                            Ring finger bent inward
# 16                  Fingers spread and curved outward
# 17                          Thumb touches ring finger
# 18              Thumb and middle joined, index raised
# 19            Thumb and index joined, others extended
#
#                                              viniyoga
# 0   [used to show sky, indicate stopping, depict w...
# 1   [depicting crown, showing tree, arrow release,...
# 2   [showing separation, depict lightning, indicat...
# 3   [depicting moon, holding platter, touching wai...
# 4   [drinking nectar, strong wind depiction, Shiva...
# 5   [archery depiction, parrot representation, whi...
# 6   [depict fighting, holding weapon, anger expres...
# 7   [holding bow, showing husband, ring ceremony, ...
# 8   [goddess depiction, holding flowers, ritual ac...
# 9   [wearing garland, decorative action, holding o...
# 10  [pointing direction, indicating one, showing sun]
# 11  [holding fruits, depicting bud, offering flowers]
# 12       [depict snake, ritual sprinkling, abhisheka]
# 13       [depict deer, Krishna flute, touching cheek]
# 14         [depict lion, holding medicine, ornaments]
# 15             [holding bell, small object depiction]
# 16          [depict lotus, show beauty, round object]
# 17      [express cleverness, indicate small quantity]
# 18                          [depict bee, secret talk]
# 19                   [holding pearl, delicate action]
